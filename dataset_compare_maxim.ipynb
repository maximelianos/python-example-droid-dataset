# %% [markdown]
# # Visualize Datasets
#
# Compare two datasets to make sure they are reasonably similar.
#
# ## Load Data

# %%
import re
from pathlib import Path
from PIL import Image
from tqdm.notebook import tqdm
import numpy as np
from data_loader_jsonl import JSONLDataset

ACTION_ENCODER = "xyzrotvec-cam-proj2"

#real_dataset_location = "/data/lmbraid19/argusm/datasets/clevr-real-1of5c-v1"
#real_dataset_location = "/data/lmbraid19/argusm/datasets/clevr-real-block-v1"
#real_dataset_location = "/mnt/lmb/datasets/clevr-real-block-v1"
real_dataset_location = "./data/clevr-real-block-v1"
real_dataset_location = Path(real_dataset_location)
real_dataset = JSONLDataset(
    jsonl_file_path=f"{real_dataset_location}/_annotations.valid.jsonl",
    image_directory_path=f"{real_dataset_location}/dataset",
)
#sim_dataset_location = "/mnt/lmn/datasets/clevr-act-6-var-cam"
sim_dataset_location = "./data/clevr-act-6-var-cam"
sim_dataset_location = Path(sim_dataset_location)
sim_dataset = JSONLDataset(
    jsonl_file_path=f"{sim_dataset_location}/_annotations.valid.jsonl",
    image_directory_path=f"{sim_dataset_location}/dataset",
)

pred_list = []
valid_sample = []

num_samples = len(real_dataset)
suffix_rs = []
suffix_ss = []
for i in tqdm(range(num_samples)):
    image_r, label_real = real_dataset[i]
    image_s, label_sim = sim_dataset[i]
    suffix_real = [int(x) for x in re.findall(r"<(?:loc|seg)(\d+)>", label_real["suffix"])]
    suffix_sim = [int(x) for x in re.findall(r"<(?:loc|seg)(\d+)>", label_sim["suffix"])]
    suffix_rs.append(suffix_real)
    suffix_ss.append(suffix_sim)

# shape (N, 12)
# (12) = (6) first point + (6) grip point
# (6) first point = (x y qw qx qy qz)
suffix_rs = np.array(suffix_rs)
suffix_ss = np.array(suffix_ss)
# Out:
#   0%|          | 0/160 [00:00<?, ?it/s]

# %% [markdown]
# ## Plot Raw Value Histograms

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(8, 8*1/2))  # 3 rows x 4 columns of histograms

names = "real", "sim"
data = (suffix_rs, suffix_ss)
for i in range(2):
    i=i+0
    # axes[0].scatter(data[i][:,0], data[i][:,1], alpha=0.7, label=names[i]+"-src")
    # axes[0].scatter(data[i][:,6], data[i][:,7], alpha=0.7, label=names[i]+"-dst")
    # axes[0].legend()
    # axes[1].hist(data[i][:,2],  bins=10, alpha=0.5,  edgecolor='black',label=names[i]+"-src")
    # axes[1].hist(data[i][:,2+6],  bins=10, alpha=0.5,  edgecolor='black',label=names[i]+"-dst")
    # axes[1].legend()
    #axes[0].scatter(data[i][:,0].tolist()+data[i][:,6].tolist(), data[i][:,1].tolist()+data[i][:,7].tolist(), alpha=0.7, label=names[i]+"")
    axes[0].scatter(data[i][:,0].tolist()+data[i][:,6].tolist(), data[i][:,1].tolist()+data[i][:,7].tolist(), alpha=0.7, label=names[i]+"")
    axes[0].set_xlabel("x positions [img-norm-px]")
    axes[0].set_ylabel("y positions [img-norm-px]")
    axes[0].legend()
    axes[1].hist(data[i][:,2].tolist()+data[i][:,2+6].tolist(),  alpha=0.5,  edgecolor='black',label=names[i]+"")
    axes[1].set_xlabel("depth [cm]")
    axes[1].set_ylabel("frequency")
    axes[1].legend()
    
#axes[0].set_title(f'Hist {action_labels[i]}')
#axes[0].set_xlabel(units[i])
#axes[0].set_ylabel('Frequency')

# %% [markdown]
# ## Analyze Text

# %%
#!pip install spacy
#!python -m spacy download en_core_web_sm

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

def extract_components(sentence):
    doc = nlp(sentence)
    verb, obj, prep, prep_obj = None, None, None, None

    for token in doc:
        if token.pos_ == "VERB":  # Extract the main verb
            verb = token.text
        elif token.dep_ == "dobj":  # Extract direct object
            obj = token.text
        elif token.dep_ == "prep":  # Extract preposition
            prep = token.text
        elif token.dep_ == "pobj":  # Extract prepositional object
            prep_obj = token.text

    return dict(verb=verb, obj=obj, prep=prep, prep_obj=prep_obj)

list_of_comp_real = []
list_of_comp_sim = []
texts = []
num_samples = len(real_dataset)
for i in tqdm(range(num_samples)):
    image_r, label_real = real_dataset[i]
    text_real = label_real["prefix"].split("<")[0].replace("\n","").lower()
    components_real = extract_components(text_real)
    list_of_comp_real.append(components_real)
    texts.append(text_real)

    image_s, label_sim = sim_dataset[i]
    text_sim = label_sim["prefix"].split("<")[0]
    components_sim = extract_components(text_sim)
    list_of_comp_sim.append(components_sim)
# Out:
#   0%|          | 0/160 [00:00<?, ?it/s]

# %%
from collections import Counter, defaultdict

def count_value_frequencies(list_of_dicts):
    key_value_counter = defaultdict(Counter)
    
    # Iterate through each dictionary
    for d in list_of_dicts:
        for key, value in d.items():
            key_value_counter[key][value] += 1  # Count value occurrences per key

    return key_value_counter

key_value_counts_real = count_value_frequencies(list_of_comp_real)
key_value_counts_sim = count_value_frequencies(list_of_comp_sim)

# Print results
for key, counter in key_value_counts_real.items():
    print(f"Key: {key}")
    for value, freq in counter.most_common():  # Sorted by frequency
        freq_sim = key_value_counts_sim[key][value]
        print(f"  Value: {value}\t freq-real: {freq} freq_sim: {freq_sim}")
    for value, freq_sim in key_value_counts_sim[key].items():
        if value not in counter:
            print(f"  Value: {value}\t freq-real: {0} freq_sim: {freq_sim}")
    print("-" * 40)


fig, axes = plt.subplots(1, 4, figsize=(18, 12 * 1/4))  # 1x3 grid of histograms
axes = axes.flatten()  # Flatten axes for easy iteration
# Plotting histograms for each POS
for i, (pos, real_counts) in enumerate(key_value_counts_real.items()):
    # Extract values and their frequencies
    all_keys = list(set(real_counts.keys()).union(set(key_value_counts_sim[pos].keys())))


    real_freq = [key_value_counts_real[pos].get(value, 0) for value in all_keys]
    sim_freq = [key_value_counts_sim[pos].get(value, 0) for value in all_keys]
    
    # Get the current axis for plotting
    ax = axes[i]
    
    # Bar width
    width = 0.35  
    x = range(len(all_keys))
    
    # Create bars for real frequencies and simulated frequencies
    ax.bar(x, real_freq, width, label='Real Freq.',  alpha=0.7)
    ax.bar(x, sim_freq, width, label='Sim. Freq.',  alpha=0.7)
    
    # Labels and Title
    ax.set_xlabel('Text')
    ax.set_ylabel('Frequency')
    #ax.set_title(f'{pos.capitalize()} Frequency')
    ax.set_ylabel(f'{pos.capitalize()} Frequency')
    ax.set_xticks([i for i in x])
    ax.set_xticklabels(all_keys, rotation=90)
    ax.legend()
plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# Key: verb
#   Value: put	 freq-real: 143 freq_sim: 0
#   Value: place	 freq-real: 17 freq_sim: 0
#   Value: move	 freq-real: 0 freq_sim: 160
# ----------------------------------------
# Key: obj
#   Value: block	 freq-real: 118 freq_sim: 0
#   Value: cube	 freq-real: 21 freq_sim: 82
#   Value: it	 freq-real: 16 freq_sim: 0
#   Value: thing	 freq-real: 2 freq_sim: 0
#   Value: box	 freq-real: 2 freq_sim: 0
#   Value: object	 freq-real: 1 freq_sim: 0
#   Value: sphere	 freq-real: 0 freq_sim: 65
#   Value: None	 freq-real: 0 freq_sim: 7
#   Value: cyan	 freq-real: 0 freq_sim: 6
# ----------------------------------------
# Key: prep
#   Value: in	 freq-real: 110 freq_sim: 0
#   Value: inside	 freq-real: 45 freq_sim: 0
#   Value: into	 freq-real: 5 freq_sim: 0
#   Value: onto	 freq-real: 0 freq_sim: 160
# ----------------------------------------
# Key: prep_obj
#   Value: cup	 freq-real: 159 freq_sim: 0
#   Value: pot	 freq-real: 1 freq_sim: 0
#   Value: cube	 freq-real: 0 freq_sim: 87
#   Value: sphere	 freq-real: 0 freq_sim: 70
#   Value: cyan	 freq-real: 0 freq_sim: 3
# ----------------------------------------

# %% [markdown]
# # Generate Similar Texts
#
# TOOD(maxim): Make a function to generate texts that mirror the original dataset
#
# (We want to simplify the original dataset .lower(), no . at the end, no space at the end)
#
# 1. Option 1: define some templates + frequency
# 2. Option 2: cout word freqeuncy and follow `/ManiSkill/mani_skill/examples/utils_env_interventions.py`

# %%
import numpy as np

print(len(texts))
print(len(set(texts)))

for text in list(set(texts)):
    print(text)
# Out:
# 160
# 37
# put the yellow block in the cup
# put the block into the cup
# place the yellow block inside the light blue cup
# place the yellow object inside the blue cup
# pick the yellow block and put it in the cup
# place the yellow block in the blue cup
# pick up the yellow object and put it in the cup
# put the yellow cube inside the light blue cup
# put the green block in the cup
# place the yellow block in the light blue cup
# place the yellow block inside the cup
# put the yellow box in the blue cup
# put the yellow block inside the light blue cup
# pick the yellow cube and put it in the cup
# put the yellow building block in the blue cup
# put the yellow block inside the blue cup
# put the yellow box in the cup
# place the yellow block inside the blue cup
# put the yellow block inside light blue cup
# put the cube in the cup
# put the yellow block into the blue cup
# pick up the yellow block and put it in the cup
# put the block in the cup
# pick up the yellow block and put it in the blue cup
# put the yellow block in the light blue cup
# place the yellow cube inside the blue cup
# put the yellow cube inside the blue cup
# put the yellow thing in the cup
# get the yellow block and place it in the blue cup
# put the yellow cube in the blue cup
# put the block inside the cup
# put the yellow block in the pot
# place the yellow block in the cup
# put the yellow cube in the cup
# put the yellow block in the blue cup
# pick up the yellow block and put it inside the cup
# put the yellow block into the cup

# %% [markdown]
# ## Simple generator

# %%
templates = """put {o} in {c}
put {o} into {c}
place {o} inside {c}
place {o} inside {c}
pick {o} and put it in {c}
place {o} in {c}
pick up {o} and put it in {c}
put {o} inside {c} 
put {o} in {c} 
place {o} in {c}
place {o} inside {c}
put {o} in {c}
put {o} inside {c}
pick {o} and put it in {c}
put {o} in {c}
put {o} inside {c}
put {o} in {c}
place {o} inside {c}
put {o} inside {c}
put the cube in {c}
put {o} into {c}
pick up {o} and put it in {c}
put {o} in {c}
pick up {o} and put it in {c}
put {o} in {c}
place {o} inside {c}
put {o} inside {c}
put {o} in {c}
get {o} and place it in {c}
put {o} in {c}
put {o} inside {c}
put {o} in {c}
place {o} in {c}
put {o} in {c}
put {o} in {c}
pick up {o} and put it inside {c}
put {o} into {c}""".split("\n")

print(len(templates))
print(len(set(templates)))
# Out:
# 37
# 12

# %%
import re

templates = sorted(set(templates))
counts = [0] * len(templates)

for i, regex in enumerate(templates):
    regex = regex.replace("{o}", ".*").replace("{c}", ".*")
    for text in texts:
        if re.findall(regex, text):
            counts[i] += 1

for regex, count in zip(templates, counts):
    print(regex, count)
# Out:
# get {o} and place it in {c} 1
# pick up {o} and put it in {c} 7
# pick up {o} and put it inside {c} 1
# pick {o} and put it in {c} 14
# place {o} in {c} 4
# place {o} inside {c} 13
# put the cube in {c} 1
# put {o} in {c} 106
# put {o} in {c}  106
# put {o} inside {c} 32
# put {o} inside {c}  32
# put {o} into {c} 5

# %% [markdown]
# ## Advanced generator

# %%
"""
pick up the yellow object and put it in the cup 
{v1}    {o}               and {v2} it {p}{c}

put the block into the cup 
{v2} {o}      {p}  {c}


v1: pick up, pick, get
v2: put, place
p: in, into, inside
o: the yellow object, the yellow block, the cube, the yellow cube, the yellow box, the block, the yellow building block, the thing
c: the cup, the blue cup, the light blue cup, the pot
"""

verb1 = "pick up,pick,get".split(",")
verb2 = "put,place".split(",")
prep = "in,into,inside".split(",")
obj = "the yellow object,the yellow block,the cube,the yellow cube,the yellow box,the block,the yellow building block".split(",")
container = "the cup,the blue cup,the light blue cup,the pot".split(",")

# %%
# calculate probabilities
def count_occurance(s):
    count = 0
    for text in set(texts):
        if s in text:
            count += 1
    return count

def normalize(arr):
    return arr / arr.sum()

verb1_proba = normalize(np.array([count_occurance(s) for s in verb1]))
verb2_proba = normalize(np.array([count_occurance(s) for s in verb2]))
prep_proba = normalize(np.array([count_occurance(s) for s in prep]))
obj_proba = normalize(np.array([count_occurance(s) for s in obj]))
container_proba = normalize(np.array([count_occurance(s) for s in container]))

for i in range(len(obj)):
    print(obj[i], "{:.2f}".format(obj_proba[i]))
# Out:
# the yellow object 0.06
# the yellow block 0.57
# the cube 0.03
# the yellow cube 0.17
# the yellow box 0.06
# the block 0.09
# the yellow building block 0.03

# %%
def generate_yellow_block_text():
    v1 = np.random.choice(verb1)
    v2 = np.random.choice(verb2)
    p = np.random.choice(prep)
    o = np.random.choice(obj)
    c = np.random.choice(container)

    v1 = np.random.choice(verb1, p=verb1_proba)
    v2 = np.random.choice(verb2, p=verb2_proba)
    p = np.random.choice(prep, p=prep_proba)
    o = np.random.choice(obj, p=obj_proba)
    c = np.random.choice(container, p=container_proba)
    
    sentence = np.random.randint(2)
    if sentence == 0:
        return f"{v1} {o} and {v2} it {p} {c}"
    else:
        return f"{v2} {o} {p} {c}"

# %%
for i in range(10):
    print(generate_yellow_block_text())
# Out:
# pick up the yellow block and place it in the blue cup
# pick up the yellow block and put it in the cup
# pick the yellow object and put it in the blue cup
# put the yellow building block inside the cup
# pick up the yellow block and put it in the blue cup
# pick the yellow block and put it in the cup
# place the yellow block in the blue cup
# put the yellow block in the light blue cup
# place the yellow object into the cup
# put the block inside the cup

# %% [markdown]
# ## Visualize Angles
#
# TODO(maxim): The angle distribution should be similar. Find out why they are different, is it because of the data or (hopelfully) because of a shift between the coordinate systems.

# %%
import matplotlib.pyplot as plt

# fig = plt.figure()
# axes = fig.add_subplot(111, projection='3d')

# names = "real", "sim"
# data = (suffix_rs, suffix_ss)
# for i in range(2):
#     axes.scatter(data[i][:,3], data[i][:,4],data[i][:,5], alpha=0.5, label=names[i])
#     #axes.scatter(data[i][:,9], data[i][:,10],data[i][:,11],alpha=0.7, label=names[i]+"-dst")
#     axes.legend()
# plt.show()

from math import pi
fig, axes = plt.subplots(1, 4, figsize=(12, 12*1/4))
names = "real", "sim"
data = (suffix_rs, suffix_ss)
for i in range(2):
    for j in range(3):
        axes[j].hist(data[i][:,3+j], label=names[i], alpha=.7)
        #axes[j].hist(data[i][:,3+j]/100-pi, alpha=0.7, label=names[i])
        #axes[0].scatter(data[i][:,6], data[i][:,7], alpha=0.7, label=names[i]+"-dst")
        axes[j].legend()
    j = 3
    norm = np.linalg.norm(data[i][:,3:6]/100-pi, axis=1)
    axes[j].hist(norm, label=names[i], alpha=.7)
    axes[j].legend()

# %%
# Plot angles to gripper
# https://stackoverflow.com/questions/31768031/plotting-points-on-the-surface-of-a-sphere

from mani_skill.examples.utils_traj_tokens import getActionEncDecFunction, decode_caption_xyzrotvec
from mani_skill.examples.utils_trajectory import DummyCamera
from scipy.spatial.transform import Rotation as R
import torch

enc, dec = getActionEncDecFunction('xyzrotvec-cam-proj')
camera = DummyCamera(intrinsic_matrix=[], extrinsic_matrix=[], width=224, height=224)

def rotation_to_spherical(rot: R):
    """
    Convert a 3D rotation (given as a scipy Rotation object) into spherical coordinates.
    Returns:
    - azimuth (longitude) φ in radians
    - elevation (latitude) θ in radians
    - rotation angle α in radians
    """
    
    # Convert rotation to axis-angle representation
    axis, angle = rot.as_rotvec(), np.linalg.norm(rot.as_rotvec())
    # Normalize the rotation axis to ensure it's a unit vector
    if np.isclose(angle, 0):  # Handle zero rotation case
        return 0, 0, 0
    unit_axis = axis / angle  # Normalize axis to lie on unit sphere
    x, y, z = unit_axis
    # Compute spherical coordinates
    azimuth = np.arctan2(y, x)  # Longitude φ
    elevation = np.arcsin(z)     # Latitude θ
    return azimuth, elevation, angle  # (φ, θ, α)

datasets = (real_dataset, sim_dataset)
dataset_names = ("real", "sim")
orns = {"real-src":[],"real-dst":[],"sim-src":[], "sim-dst":[]}

limit = min([len(x) for x in datasets])
for i in range(len(datasets)):
    dataset_name = dataset_names[i]
    for j in range(len(datasets[i])):    
        suffix = datasets[i][j][1]["suffix"]
        dec_gt = decode_caption_xyzrotvec(suffix, camera)
        orns_R = R.from_quat(dec_gt[1][0], scalar_first=True)
        orns[dataset_name+"-src"].append(orns_R)
        
        orns_R = R.from_quat(dec_gt[1][1], scalar_first=True)
        orns[dataset_name+"-dst"].append(orns_R)
        if j == limit -1:
            break
print("done.")
#sphericals = np.array(sphericals)

# %%
# TODO(maxim): ideally this plot looks similar to the xy image position ones where sim is a superset of real.

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(len(datasets)):
    dataset_name = dataset_names[i]
    cur = np.array([x.as_rotvec() for x in orns[dataset_name+"-src"]])
    ax.scatter(cur[:,0], cur[:,1], cur[:,2], label=dataset_name+"")
    ax.set_xlabel("r1 [rad]")
    ax.set_ylabel("r2 [rad]")
    ax.set_zlabel("r3 [rad]")
    
    #cur = np.array([x.as_rotvec() for x in orns[dataset_name+"-dst"]])
    #ax.scatter(cur[:,0], cur[:,1], cur[:,2], label=dataset_name+"-dst")
                
plt.legend()
plt.show()

# %% [markdown]
# # Visualize Images

# %%
from utils_vis import render_example

html_imgs = ""
for i in tqdm(range(num_samples)):
    image_r, label_real = real_dataset[i]
    image_s, label_sim = sim_dataset[i]
    html_imgs += render_example(image_r, label=label_real["suffix"], prediction=None, text=label_real["prefix"])
    html_imgs += render_example(image_s, label=label_sim["suffix"], prediction=None, text=label_sim["prefix"])

    if i > 10:
        break
plot_images = True
if plot_images:
    from IPython.display import display, HTML
    display(HTML(html_imgs))
