# %%
import re
from pathlib import Path
from PIL import Image
from tqdm.notebook import tqdm
import numpy as np

import os
import json
from PIL import Image
from torch.utils.data import Dataset


class JSONLDataset(Dataset):
    def __init__(self, jsonl_file_path: str, image_directory_path: str):
        self.jsonl_file_path = jsonl_file_path
        self.image_directory_path = image_directory_path
        self.entries = self._load_entries()

    def _load_entries(self):
        entries = []
        with open(self.jsonl_file_path, 'r') as file:
            for line in file:
                data = json.loads(line)
                entries.append(data)
        return entries

    def __len__(self):
        return len(self.entries)

    def __getitem__(self, idx: int):
        if idx < 0 or idx >= len(self.entries):
            raise IndexError("Index out of range")

        entry = self.entries[idx]
        image_path = os.path.join(self.image_directory_path, entry['image'])
        image = Image.open(image_path)
        return image, entry


ACTION_ENCODER = "xyzrotvec-cam-proj"

real_dataset_location = "./data/export-real-1of5-checked"
real_dataset_location = Path(real_dataset_location)
real_dataset = JSONLDataset(
    jsonl_file_path=f"{real_dataset_location}/_annotations.all.jsonl",
    image_directory_path=f"{real_dataset_location}",
)
sim_dataset_location = "./data/export-real-1of5-checked"
sim_dataset_location = Path(sim_dataset_location)
sim_dataset = JSONLDataset(
    jsonl_file_path=f"{sim_dataset_location}/_annotations.all.jsonl",
    image_directory_path=f"{sim_dataset_location}",
)

# %%
pred_list = []
valid_sample = []

num_samples = len(real_dataset)
suffix_rs = []
suffix_ss = []
for i in tqdm(range(num_samples)):
    image_r, label_real = real_dataset[i]
    image_s, label_sim = sim_dataset[i]
    suffix_real = [int(x) for x in re.findall(r"<loc(\d{4})>", label_real["suffix"])]
    suffix_sim = [int(x) for x in re.findall(r"<loc(\d{4})>", label_sim["suffix"])]
    suffix_rs.append(suffix_real)
    suffix_ss.append(suffix_sim)

suffix_rs = np.array(suffix_rs)
suffix_ss = np.array(suffix_ss)
# Out:
#   0%|          | 0/1293 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 10
#       8 image_r, label_real = real_dataset[i]
#       9 image_s, label_sim = sim_dataset[i]
# ---> 10 suffix_real = [int(x) for x in re.findall(r"<loc(\d{4})>", label_real["suffix"])]
#      11 suffix_sim = [int(x) for x in re.findall(r"<loc(\d{4})>", label_sim["suffix"])]
#      12 suffix_rs.append(suffix_real)
#
# KeyError: 'suffix'

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(12, 12*1/3))  # 3 rows x 4 columns of histograms

names = "real", "sim"
data = (suffix_rs, suffix_ss)
for i in range(2):
    i=i+0
    axes[0].scatter(data[i][:,0], data[i][:,1], alpha=0.7, label=names[i])
    axes[0].scatter(data[i][:,6], data[i][:,7], alpha=0.7, label=names[i]+"-dst")
    axes[0].legend()
    axes[1].hist(data[i][:,2],  bins=10, alpha=0.5,  edgecolor='black',label=names[i])
    axes[1].hist(data[i][:,2+6],  bins=10, alpha=0.5,  edgecolor='black',label=names[i]+"-dst")
    axes[1].legend()
    
#axes[0].set_title(f'Hist {action_labels[i]}')
#axes[0].set_xlabel(units[i])
#axes[0].set_ylabel('Frequency')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 9
#       7 for i in range(2):
#       8     i=i+0
# ----> 9     axes[0].scatter(data[i][:,0], data[i][:,1], alpha=0.7, label=names[i])
#      10     axes[0].scatter(data[i][:,6], data[i][:,7], alpha=0.7, label=names[i]+"-dst")
#      11     axes[0].legend()
#
# TypeError: list indices must be integers or slices, not tuple

# %%
#!pip install spacy
#!python -m spacy download en_core_web_sm

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

def extract_components(sentence):
    doc = nlp(sentence)
    verb, obj, prep, prep_obj = None, None, None, None

    for token in doc:
        if token.pos_ == "VERB":  # Extract the main verb
            verb = token.text
        elif token.dep_ == "dobj":  # Extract direct object
            obj = token.text
        elif token.dep_ == "prep":  # Extract preposition
            prep = token.text
        elif token.dep_ == "pobj":  # Extract prepositional object
            prep_obj = token.text

    return dict(verb=verb, obj=obj, prep=prep, prep_obj=prep_obj)

list_of_comp_real = []
list_of_comp_sim = []
texts = []
num_samples = len(real_dataset)
for i in tqdm(range(num_samples)):
    image_r, label_real = real_dataset[i]
    text_real = label_real["action_text"].split("<")[0].replace("\n","").lower()
    components_real = extract_components(text_real)
    list_of_comp_real.append(components_real)

    image_s, label_sim = sim_dataset[i]
    text_sim = label_sim["action_text"].split("<")[0]
    components_sim = extract_components(text_sim)
    list_of_comp_sim.append(components_sim)
# Out:
#   0%|          | 0/1293 [00:00<?, ?it/s]

# %%
from collections import Counter, defaultdict

def count_value_frequencies(list_of_dicts):
    key_value_counter = defaultdict(Counter)
    
    # Iterate through each dictionary
    for d in list_of_dicts:
        for key, value in d.items():
            key_value_counter[key][value] += 1  # Count value occurrences per key

    return key_value_counter

key_value_counts_real = count_value_frequencies(list_of_comp_real)
key_value_counts_sim = count_value_frequencies(list_of_comp_sim)

# Print results
for key, counter in key_value_counts_real.items():
    print(f"Key: {key}")
    for value, freq in counter.most_common():  # Sorted by frequency
        freq_sim = key_value_counts_sim[key][value]
        print(f"  Value: {value}\t freq-real: {freq} freq_sim: {freq_sim}")
    for value, freq_sim in key_value_counts_sim[key].items():
        if value not in counter:
            print(f"  Value: {value}\t freq-real: {0} freq_sim: {freq_sim}")
    print("-" * 40)


fig, axes = plt.subplots(1, 4, figsize=(18, 12 * 1/4))  # 1x3 grid of histograms
axes = axes.flatten()  # Flatten axes for easy iteration
# Plotting histograms for each POS
for i, (pos, real_counts) in enumerate(key_value_counts_real.items()):
    # Extract values and their frequencies
    all_keys = list(set(real_counts.keys()).union(set(key_value_counts_sim[pos].keys())))


    real_freq = [key_value_counts_real[pos].get(value, 0) for value in all_keys]
    sim_freq = [key_value_counts_sim[pos].get(value, 0) for value in all_keys]
    
    # Get the current axis for plotting
    ax = axes[i]
    
    # Bar width
    width = 0.35  
    x = range(len(all_keys))
    
    # Create bars for real frequencies and simulated frequencies
    ax.bar(x, real_freq, width, label='Real Freq.',  alpha=0.7)
    ax.bar(x, sim_freq, width, label='Sim. Freq.',  alpha=0.7)
    
    # Labels and Title
    ax.set_xlabel('Text')
    ax.set_ylabel('Frequency')
    #ax.set_title(f'{pos.capitalize()} Frequency')
    ax.set_ylabel(f'{pos.capitalize()} Frequency')
    ax.set_xticks([i for i in x])
    ax.set_xticklabels(all_keys, rotation=90)
    ax.legend()
plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# Key: verb
#   Value: put	 freq-real: 716 freq_sim: 716
#   Value: move	 freq-real: 168 freq_sim: 168
#   Value: place	 freq-real: 116 freq_sim: 116
#   Value: remove	 freq-real: 64 freq_sim: 64
#   Value: close	 freq-real: 60 freq_sim: 60
#   Value: pour	 freq-real: 36 freq_sim: 36
#   Value: take	 freq-real: 28 freq_sim: 28
#   Value: open	 freq-real: 14 freq_sim: 14
#   Value: pull	 freq-real: 11 freq_sim: 11
#   Value: cover	 freq-real: 8 freq_sim: 8
#   Value: measuring	 freq-real: 6 freq_sim: 6
#   Value: push	 freq-real: 5 freq_sim: 5
#   Value: slide	 freq-real: 4 freq_sim: 4
#   Value: stack	 freq-real: 4 freq_sim: 4
#   Value: bar	 freq-real: 4 freq_sim: 4
#   Value: arrange	 freq-real: 4 freq_sim: 4
#   Value: pick	 freq-real: 3 freq_sim: 3
#   Value: left	 freq-real: 3 freq_sim: 3
#   Value: uncover	 freq-real: 3 freq_sim: 3
#   Value: transfer	 freq-real: 3 freq_sim: 3
#   Value: stuffed	 freq-real: 3 freq_sim: 3
#   Value: plug	 freq-real: 3 freq_sim: 3
#   Value: None	 freq-real: 2 freq_sim: 2
#   Value: shift	 freq-real: 2 freq_sim: 2
#   Value: set	 freq-real: 2 freq_sim: 2
#   Value: striped	 freq-real: 2 freq_sim: 2
#   Value: placing	 freq-real: 2 freq_sim: 2
#   Value: rotate	 freq-real: 2 freq_sim: 2
#   Value: facing	 freq-real: 1 freq_sim: 1
#   Value: hang	 freq-real: 1 freq_sim: 1
#   Value: attach	 freq-real: 1 freq_sim: 1
#   Value: lean	 freq-real: 1 freq_sim: 1
#   Value: plush	 freq-real: 1 freq_sim: 1
#   Value: strawberry	 freq-real: 1 freq_sim: 1
#   Value: press	 freq-real: 1 freq_sim: 1
#   Value: disappointed	 freq-real: 1 freq_sim: 1
#   Value: position	 freq-real: 1 freq_sim: 1
#   Value: wipe	 freq-real: 1 freq_sim: 1
#   Value: closed	 freq-real: 1 freq_sim: 1
#   Value: drop	 freq-real: 1 freq_sim: 1
#   Value: shake	 freq-real: 1 freq_sim: 1
#   Value: return	 freq-real: 1 freq_sim: 1
#   Value: attached	 freq-real: 1 freq_sim: 1
# ----------------------------------------
# Key: obj
#   Value: it	 freq-real: 320 freq_sim: 320
#   Value: marker	 freq-real: 128 freq_sim: 128
#   Value: block	 freq-real: 91 freq_sim: 91
#   Value: cup	 freq-real: 64 freq_sim: 64
#   Value: object	 freq-real: 49 freq_sim: 49
#   Value: pen	 freq-real: 38 freq_sim: 38
#   Value: drawer	 freq-real: 36 freq_sim: 36
#   Value: lid	 freq-real: 36 freq_sim: 36
#   Value: can	 freq-real: 30 freq_sim: 30
#   Value: contents	 freq-real: 29 freq_sim: 29
#   Value: cube	 freq-real: 27 freq_sim: 27
#   Value: them	 freq-real: 21 freq_sim: 21
#   Value: packet	 freq-real: 20 freq_sim: 20
#   Value: blocks	 freq-real: 19 freq_sim: 19
#   Value: toy	 freq-real: 18 freq_sim: 18
#   Value: bottle	 freq-real: 17 freq_sim: 17
#   Value: bowl	 freq-real: 16 freq_sim: 16
#   Value: door	 freq-real: 16 freq_sim: 16
#   Value: mug	 freq-real: 15 freq_sim: 15
#   Value: bar	 freq-real: 14 freq_sim: 14
#   Value: pot	 freq-real: 13 freq_sim: 13
#   Value: box	 freq-real: 11 freq_sim: 11
#   Value: ring	 freq-real: 10 freq_sim: 10
#   Value: plushie	 freq-real: 9 freq_sim: 9
#   Value: tape	 freq-real: 8 freq_sim: 8
#   Value: soda	 freq-real: 7 freq_sim: 7
#   Value: thing	 freq-real: 7 freq_sim: 7
#   Value: pillows	 freq-real: 7 freq_sim: 7
#   Value: fork	 freq-real: 6 freq_sim: 6
#   Value: spoon	 freq-real: 6 freq_sim: 6
#   Value: shaker	 freq-real: 6 freq_sim: 6
#   Value: stick	 freq-real: 5 freq_sim: 5
#   Value: item	 freq-real: 5 freq_sim: 5
#   Value: basket	 freq-real: 5 freq_sim: 5
#   Value: cob	 freq-real: 5 freq_sim: 5
#   Value: cups	 freq-real: 5 freq_sim: 5
#   Value: cellar	 freq-real: 5 freq_sim: 5
#   Value: wrench	 freq-real: 5 freq_sim: 5
#   Value: bull	 freq-real: 4 freq_sim: 4
#   Value: things	 freq-real: 4 freq_sim: 4
#   Value: knife	 freq-real: 4 freq_sim: 4
#   Value: cylinder	 freq-real: 4 freq_sim: 4
#   Value: screwdriver	 freq-real: 4 freq_sim: 4
#   Value: cubes	 freq-real: 4 freq_sim: 4
#   Value: pepper	 freq-real: 4 freq_sim: 4
#   Value: donut	 freq-real: 4 freq_sim: 4
#   Value: sharpie	 freq-real: 3 freq_sim: 3
#   Value: egg	 freq-real: 3 freq_sim: 3
#   Value: container	 freq-real: 3 freq_sim: 3
#   Value: pack	 freq-real: 3 freq_sim: 3
#   Value: spatula	 freq-real: 3 freq_sim: 3
#   Value: banana	 freq-real: 3 freq_sim: 3
#   Value: plate	 freq-real: 3 freq_sim: 3
#   Value: forks	 freq-real: 3 freq_sim: 3
#   Value: disk	 freq-real: 3 freq_sim: 3
#   Value: book	 freq-real: 3 freq_sim: 3
#   Value: animal	 freq-real: 3 freq_sim: 3
#   Value: ball	 freq-real: 3 freq_sim: 3
#   Value: objects	 freq-real: 3 freq_sim: 3
#   Value: glue	 freq-real: 2 freq_sim: 2
#   Value: bag	 freq-real: 2 freq_sim: 2
#   Value: purple	 freq-real: 2 freq_sim: 2
#   Value: side	 freq-real: 2 freq_sim: 2
#   Value: handle	 freq-real: 2 freq_sim: 2
#   Value: one	 freq-real: 2 freq_sim: 2
#   Value: orange	 freq-real: 2 freq_sim: 2
#   Value: sprite	 freq-real: 2 freq_sim: 2
#   Value: snickers	 freq-real: 2 freq_sim: 2
#   Value: None	 freq-real: 2 freq_sim: 2
#   Value: plushy	 freq-real: 2 freq_sim: 2
#   Value: books	 freq-real: 2 freq_sim: 2
#   Value: toys	 freq-real: 2 freq_sim: 2
#   Value: tomato	 freq-real: 2 freq_sim: 2
#   Value: head	 freq-real: 2 freq_sim: 2
#   Value: bottles	 freq-real: 2 freq_sim: 2
#   Value: plush	 freq-real: 2 freq_sim: 2
#   Value: remote	 freq-real: 2 freq_sim: 2
#   Value: shoe	 freq-real: 2 freq_sim: 2
#   Value: chip	 freq-real: 2 freq_sim: 2
#   Value: teabag	 freq-real: 1 freq_sim: 1
#   Value: basin	 freq-real: 1 freq_sim: 1
#   Value: content	 freq-real: 1 freq_sim: 1
#   Value: bin	 freq-real: 1 freq_sim: 1
#   Value: rod	 freq-real: 1 freq_sim: 1
#   Value: maize	 freq-real: 1 freq_sim: 1
#   Value: cola	 freq-real: 1 freq_sim: 1
#   Value: doll	 freq-real: 1 freq_sim: 1
#   Value: fritos	 freq-real: 1 freq_sim: 1
#   Value: snack	 freq-real: 1 freq_sim: 1
#   Value: lays	 freq-real: 1 freq_sim: 1
#   Value: which	 freq-real: 1 freq_sim: 1
#   Value: nozzle	 freq-real: 1 freq_sim: 1
#   Value: spout	 freq-real: 1 freq_sim: 1
#   Value: lemons	 freq-real: 1 freq_sim: 1
#   Value: fruits	 freq-real: 1 freq_sim: 1
#   Value: fries	 freq-real: 1 freq_sim: 1
#   Value: booklet	 freq-real: 1 freq_sim: 1
#   Value: grape	 freq-real: 1 freq_sim: 1
#   Value: tiger	 freq-real: 1 freq_sim: 1
#   Value: toothpaste	 freq-real: 1 freq_sim: 1
#   Value: disc	 freq-real: 1 freq_sim: 1
#   Value: broccoli	 freq-real: 1 freq_sim: 1
#   Value: doritos	 freq-real: 1 freq_sim: 1
#   Value: button	 freq-real: 1 freq_sim: 1
#   Value: pizza	 freq-real: 1 freq_sim: 1
#   Value: markers	 freq-real: 1 freq_sim: 1
#   Value: jacket	 freq-real: 1 freq_sim: 1
#   Value: balls	 freq-real: 1 freq_sim: 1
#   Value: paper	 freq-real: 1 freq_sim: 1
#   Value: adapter	 freq-real: 1 freq_sim: 1
#   Value: cupcake	 freq-real: 1 freq_sim: 1
#   Value: eggplant	 freq-real: 1 freq_sim: 1
#   Value: tabletop	 freq-real: 1 freq_sim: 1
#   Value: carton	 freq-real: 1 freq_sim: 1
#   Value: napkin	 freq-real: 1 freq_sim: 1
#   Value: green	 freq-real: 1 freq_sim: 1
#   Value: sponge	 freq-real: 1 freq_sim: 1
#   Value: plushies	 freq-real: 1 freq_sim: 1
#   Value: watermelon	 freq-real: 1 freq_sim: 1
#   Value: scissors	 freq-real: 1 freq_sim: 1
#   Value: rectangle	 freq-real: 1 freq_sim: 1
#   Value: square	 freq-real: 1 freq_sim: 1
#   Value: stack	 freq-real: 1 freq_sim: 1
#   Value: sacket	 freq-real: 1 freq_sim: 1
#   Value: food	 freq-real: 1 freq_sim: 1
#   Value: jar	 freq-real: 1 freq_sim: 1
#   Value: cylinders	 freq-real: 1 freq_sim: 1
#   Value: sachet	 freq-real: 1 freq_sim: 1
#   Value: straw	 freq-real: 1 freq_sim: 1
#   Value: elastic	 freq-real: 1 freq_sim: 1
#   Value: pencil	 freq-real: 1 freq_sim: 1
#   Value: rubber	 freq-real: 1 freq_sim: 1
# ----------------------------------------
# Key: prep
#   Value: in	 freq-real: 399 freq_sim: 399
#   Value: on	 freq-real: 315 freq_sim: 315
#   Value: of	 freq-real: 130 freq_sim: 130
#   Value: to	 freq-real: 122 freq_sim: 122
#   Value: inside	 freq-real: 95 freq_sim: 95
#   Value: None	 freq-real: 75 freq_sim: 75
#   Value: from	 freq-real: 65 freq_sim: 65
#   Value: into	 freq-real: 61 freq_sim: 61
#   Value: onto	 freq-real: 8 freq_sim: 8
#   Value: against	 freq-real: 4 freq_sim: 4
#   Value: under	 freq-real: 3 freq_sim: 3
#   Value: with	 freq-real: 3 freq_sim: 3
#   Value: off	 freq-real: 3 freq_sim: 3
#   Value: above	 freq-real: 2 freq_sim: 2
#   Value: atop	 freq-real: 2 freq_sim: 2
#   Value: underneath	 freq-real: 1 freq_sim: 1
#   Value: up	 freq-real: 1 freq_sim: 1
#   Value: towards	 freq-real: 1 freq_sim: 1
#   Value: except	 freq-real: 1 freq_sim: 1
#   Value: by	 freq-real: 1 freq_sim: 1
#   Value: around	 freq-real: 1 freq_sim: 1
# ----------------------------------------
# Key: prep_obj
#   Value: bowl	 freq-real: 196 freq_sim: 196
#   Value: table	 freq-real: 170 freq_sim: 170
#   Value: cup	 freq-real: 161 freq_sim: 161
#   Value: None	 freq-real: 76 freq_sim: 76
#   Value: pot	 freq-real: 71 freq_sim: 71
#   Value: sink	 freq-real: 59 freq_sim: 59
#   Value: left	 freq-real: 58 freq_sim: 58
#   Value: right	 freq-real: 56 freq_sim: 56
#   Value: cabinet	 freq-real: 48 freq_sim: 48
#   Value: drawer	 freq-real: 47 freq_sim: 47
#   Value: counter	 freq-real: 37 freq_sim: 37
#   Value: mug	 freq-real: 32 freq_sim: 32
#   Value: plate	 freq-real: 25 freq_sim: 25
#   Value: shelf	 freq-real: 23 freq_sim: 23
#   Value: block	 freq-real: 23 freq_sim: 23
#   Value: box	 freq-real: 13 freq_sim: 13
#   Value: object	 freq-real: 10 freq_sim: 10
#   Value: pan	 freq-real: 10 freq_sim: 10
#   Value: tray	 freq-real: 8 freq_sim: 8
#   Value: bottle	 freq-real: 8 freq_sim: 8
#   Value: desk	 freq-real: 7 freq_sim: 7
#   Value: countertop	 freq-real: 6 freq_sim: 6
#   Value: top	 freq-real: 6 freq_sim: 6
#   Value: stand	 freq-real: 6 freq_sim: 6
#   Value: container	 freq-real: 5 freq_sim: 5
#   Value: holder	 freq-real: 5 freq_sim: 5
#   Value: one	 freq-real: 5 freq_sim: 5
#   Value: stack	 freq-real: 5 freq_sim: 5
#   Value: stove	 freq-real: 5 freq_sim: 5
#   Value: lid	 freq-real: 4 freq_sim: 4
#   Value: cube	 freq-real: 4 freq_sim: 4
#   Value: cupboard	 freq-real: 4 freq_sim: 4
#   Value: you	 freq-real: 4 freq_sim: 4
#   Value: rack	 freq-real: 4 freq_sim: 4
#   Value: jar	 freq-real: 4 freq_sim: 4
#   Value: bag	 freq-real: 4 freq_sim: 4
#   Value: spray	 freq-real: 3 freq_sim: 3
#   Value: mat	 freq-real: 3 freq_sim: 3
#   Value: platform	 freq-real: 3 freq_sim: 3
#   Value: armrest	 freq-real: 3 freq_sim: 3
#   Value: microwave	 freq-real: 3 freq_sim: 3
#   Value: vase	 freq-real: 2 freq_sim: 2
#   Value: marker	 freq-real: 2 freq_sim: 2
#   Value: it	 freq-real: 2 freq_sim: 2
#   Value: basket	 freq-real: 2 freq_sim: 2
#   Value: couch	 freq-real: 2 freq_sim: 2
#   Value: orange	 freq-real: 2 freq_sim: 2
#   Value: board	 freq-real: 2 freq_sim: 2
#   Value: dish	 freq-real: 2 freq_sim: 2
#   Value: chair	 freq-real: 2 freq_sim: 2
#   Value: bin	 freq-real: 2 freq_sim: 2
#   Value: put	 freq-real: 2 freq_sim: 2
#   Value: shelves	 freq-real: 2 freq_sim: 2
#   Value: pack	 freq-real: 2 freq_sim: 2
#   Value: notebook	 freq-real: 1 freq_sim: 1
#   Value: glass	 freq-real: 1 freq_sim: 1
#   Value: lunchbox	 freq-real: 1 freq_sim: 1
#   Value: book	 freq-real: 1 freq_sim: 1
#   Value: unit	 freq-real: 1 freq_sim: 1
#   Value: other	 freq-real: 1 freq_sim: 1
#   Value: basin	 freq-real: 1 freq_sim: 1
#   Value: can	 freq-real: 1 freq_sim: 1
#   Value: cylinder	 freq-real: 1 freq_sim: 1
#   Value: blocks	 freq-real: 1 freq_sim: 1
#   Value: paper	 freq-real: 1 freq_sim: 1
#   Value: bowls	 freq-real: 1 freq_sim: 1
#   Value: base	 freq-real: 1 freq_sim: 1
#   Value: pillow	 freq-real: 1 freq_sim: 1
#   Value: sofa	 freq-real: 1 freq_sim: 1
#   Value: oven	 freq-real: 1 freq_sim: 1
#   Value: remote	 freq-real: 1 freq_sim: 1
#   Value: gift	 freq-real: 1 freq_sim: 1
#   Value: packet	 freq-real: 1 freq_sim: 1
#   Value: dishwater	 freq-real: 1 freq_sim: 1
#   Value: adapter	 freq-real: 1 freq_sim: 1
#   Value: cord	 freq-real: 1 freq_sim: 1
#   Value: extension	 freq-real: 1 freq_sim: 1
#   Value: tabletop	 freq-real: 1 freq_sim: 1
#   Value: toolbox	 freq-real: 1 freq_sim: 1
#   Value: corner	 freq-real: 1 freq_sim: 1
#   Value: jug	 freq-real: 1 freq_sim: 1
#   Value: thing	 freq-real: 1 freq_sim: 1
#   Value: filters	 freq-real: 1 freq_sim: 1
#   Value: toy	 freq-real: 1 freq_sim: 1
#   Value: fridge	 freq-real: 1 freq_sim: 1
#   Value: dryer	 freq-real: 1 freq_sim: 1
#   Value: gameboard	 freq-real: 1 freq_sim: 1
#   Value: pallet	 freq-real: 1 freq_sim: 1
#   Value: game	 freq-real: 1 freq_sim: 1
#   Value: stovetop	 freq-real: 1 freq_sim: 1
#   Value: side	 freq-real: 1 freq_sim: 1
#   Value: fryer	 freq-real: 1 freq_sim: 1
#   Value: coffee	 freq-real: 1 freq_sim: 1
#   Value: bottom	 freq-real: 1 freq_sim: 1
#   Value: napkin	 freq-real: 1 freq_sim: 1
#   Value: maker	 freq-real: 1 freq_sim: 1
#   Value: back	 freq-real: 1 freq_sim: 1
# ----------------------------------------

# %% [markdown]
# ## Visualize Angles

# %%
import matplotlib.pyplot as plt

# fig = plt.figure()
# axes = fig.add_subplot(111, projection='3d')

# names = "real", "sim"
# data = (suffix_rs, suffix_ss)
# for i in range(2):
#     axes.scatter(data[i][:,3], data[i][:,4],data[i][:,5], alpha=0.5, label=names[i])
#     #axes.scatter(data[i][:,9], data[i][:,10],data[i][:,11],alpha=0.7, label=names[i]+"-dst")
#     axes.legend()
# plt.show()

from math import pi
fig, axes = plt.subplots(1, 3, figsize=(12, 12*1/3))
names = "real", "sim"
data = (suffix_rs, suffix_ss)
for i in range(2):
    for j in range(3):
        norm = np.linalg.norm(data[i][:,3:6]/100-pi, axis=1)

        axes[j].hist(norm, label=names[i], alpha=.7)
        #axes[j].hist(data[i][:,3+j]/100-pi, alpha=0.7, label=names[i])
        #axes[0].scatter(data[i][:,6], data[i][:,7], alpha=0.7, label=names[i]+"-dst")
        
        axes[j].legend()

# %%
# Plot angles to gripper
# https://stackoverflow.com/questions/31768031/plotting-points-on-the-surface-of-a-sphere

from mani_skill.examples.utils_traj_tokens import getActionEncDecFunction, decode_caption_xyzrotvec
from mani_skill.examples.utils_trajectory import DummyCamera
from scipy.spatial.transform import Rotation as R
import torch

enc, dec = getActionEncDecFunction('xyzrotvec-cam-proj')
camera = DummyCamera(intrinsic_matrix=[], extrinsic_matrix=[], width=224, height=224)

def rotation_to_spherical(rot: R):
    """
    Convert a 3D rotation (given as a scipy Rotation object) into spherical coordinates.
    Returns:
    - azimuth (longitude) φ in radians
    - elevation (latitude) θ in radians
    - rotation angle α in radians
    """
    
    # Convert rotation to axis-angle representation
    axis, angle = rot.as_rotvec(), np.linalg.norm(rot.as_rotvec())
    # Normalize the rotation axis to ensure it's a unit vector
    if np.isclose(angle, 0):  # Handle zero rotation case
        return 0, 0, 0
    unit_axis = axis / angle  # Normalize axis to lie on unit sphere
    x, y, z = unit_axis
    # Compute spherical coordinates
    azimuth = np.arctan2(y, x)  # Longitude φ
    elevation = np.arcsin(z)     # Latitude θ
    return azimuth, elevation, angle  # (φ, θ, α)

datasets = (real_dataset, sim_dataset)
dataset_names = ("real", "sim")
sphericals = ([], [])

limit = min([len(x) for x in datasets])
for i in range(len(datasets)):
    for j in range(len(datasets[i])):    
        suffix = datasets[i][j][1]["suffix"]
        dec_gt = decode_caption_xyzrotvec(suffix, camera)
        orns_R = R.from_quat(dec_gt[1][:2], scalar_first=True)
        sphericals[i].append(rotation_to_spherical(orns_R[0]))
        if j == limit -1:
            break
    
sphericals = np.array(sphericals)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(len(datasets)):
    spherical_sim = sphericals[i]
    ax.scatter(spherical_sim[:,0],spherical_sim[:,1], spherical_sim[:,2],s=20, label=dataset_names[i])
plt.legend()
plt.show()
