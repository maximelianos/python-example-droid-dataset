# %%
import requests

import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForZeroShotObjectDetection

model_id = "IDEA-Research/grounding-dino-base"

processor = AutoProcessor.from_pretrained(model_id)
device = "cuda"
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)
# Out:
# 2024-07-25 11:24:02.082844: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-25 11:24:02.098265: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-25 11:24:02.098290: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-25 11:24:02.107861: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-25 11:24:02.777683: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from pathlib import Path

def run_sam(image, text):
    inputs = processor(images=image, text=text, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = model(**inputs)
    
    # convert outputs (bounding boxes and class logits) to COCO API
    
    target_sizes = torch.tensor([image.size[::-1]])
    
    results = processor.image_processor.post_process_object_detection(
    
        outputs, threshold=0.35, target_sizes=target_sizes
    
    )[0]

    box_list = []
    for score, label, box in zip(results["scores"], results["labels"], results["boxes"]):
    
        box = [round(i, 1) for i in box.tolist()]
        conf = round(score.item(), 2)
        box_list.append((box, conf))
    
        print(f"Detected {label.item()} with confidence " f"{round(score.item(), 2)} at location {box}")
    return box_list

# %%
import json

import ultralytics
from ultralytics.utils.plotting import Annotator
import cv2

file_list = sorted(Path("plot/f1").glob("*jpg"))
print("episodes:", len(file_list))
# file_list = file_list[:2]

box_list = [] # list(image); image=(filename, boxes); boxes=((x,y,x,y), conf), ...

for file in file_list:
    print(file)
    image = Image.open(file)
    # Check for cats and remote controls
    text = "a pen."

    boxes = run_sam(image, text) # detections=list( ((x,y,x,y), conf) )
    box_list.append((file.stem, boxes))
    # better safe than sorry
    with open("data/boxes.json", "w") as f:
        json.dump(box_list, f, indent=4, ensure_ascii=False)

    plot_path = Path("plot/detect") / (file.name)
    plot_path.parent.mkdir(parents=True, exist_ok=True)

    annotator = Annotator(image)
    for box, conf in boxes:
        annotator.box_label(box, label=str(conf), color=(0, 204, 0)) # The bounding box coordinates (x1, y1, x2, y2)
    
    result = annotator.result()
    cv2.imwrite(plot_path, cv2.cvtColor(result, cv2.COLOR_RGB2BGR), [cv2.IMWRITE_JPEG_QUALITY, 100])
# Out:
# episodes: 100
# plot/f1/2023-03-02-15h-03m-35s.jpg
# plot/f1/2023-03-02-16h-51m-12s.jpg
# Detected 1 with confidence 0.42 at location [637.4, 431.0, 708.3, 452.1]
# plot/f1/2023-03-02-18h-13m-38s.jpg
# Detected 1 with confidence 0.53 at location [565.0, 562.0, 673.2, 601.1]
# plot/f1/2023-03-03-15h-30m-17s.jpg
# Detected 1 with confidence 0.42 at location [538.0, 359.1, 682.0, 407.5]
# plot/f1/2023-03-06-16h-02m-37s.jpg
# Detected 1 with confidence 0.49 at location [740.7, 427.2, 886.6, 489.2]
# plot/f1/2023-03-06-17h-06m-52s.jpg
# Detected 1 with confidence 0.43 at location [651.6, 379.2, 696.3, 446.9]
# plot/f1/2023-03-07-15h-36m-10s.jpg
# Detected 1 with confidence 0.43 at location [676.0, 351.4, 741.2, 382.8]
# plot/f1/2023-03-07-16h-20m-41s.jpg
# plot/f1/2023-03-07-17h-59m-19s.jpg
# plot/f1/2023-03-08-13h-29m-47s.jpg
# plot/f1/2023-03-08-14h-45m-19s.jpg
# Detected 1 with confidence 0.49 at location [780.7, 403.2, 858.7, 451.7]
# plot/f1/2023-03-08-16h-45m-10s.jpg
# Detected 1 with confidence 0.55 at location [816.3, 435.1, 900.4, 498.0]
# plot/f1/2023-03-08-19h-32m-03s.jpg
# Detected 1 with confidence 0.55 at location [578.2, 562.9, 611.4, 631.6]
# plot/f1/2023-03-08-19h-51m-18s.jpg
# Detected 1 with confidence 0.4 at location [550.4, 457.0, 599.1, 496.6]
# plot/f1/2023-03-09-18h-14m-34s.jpg
# Detected 1 with confidence 0.41 at location [722.0, 452.9, 740.3, 498.6]
# plot/f1/2023-03-09-18h-47m-35s.jpg
# Detected 1 with confidence 0.38 at location [594.0, 377.2, 664.2, 405.3]
# plot/f1/2023-03-09-19h-48m-15s.jpg
# Detected 1 with confidence 0.39 at location [703.0, 327.4, 788.0, 353.1]
# plot/f1/2023-04-07-13h-32m-40s.jpg
# Detected 1 with confidence 0.42 at location [872.6, 359.8, 897.8, 413.3]
# plot/f1/2023-04-12-14h-13m-32s.jpg
# Detected 1 with confidence 0.49 at location [539.5, 303.5, 614.6, 356.8]
# plot/f1/2023-04-12-15h-09m-51s.jpg
# plot/f1/2023-04-12-15h-34m-49s.jpg
# plot/f1/2023-04-12-15h-59m-04s.jpg
# Detected 1 with confidence 0.45 at location [737.9, 367.0, 860.4, 406.5]
# plot/f1/2023-04-12-16h-45m-27s.jpg
# Detected 1 with confidence 0.43 at location [690.9, 430.0, 827.3, 465.9]
# plot/f1/2023-04-13-15h-21m-15s.jpg
# Detected 1 with confidence 0.46 at location [341.0, 629.3, 399.3, 708.2]
# plot/f1/2023-04-17-14h-47m-13s.jpg
# Detected 1 with confidence 0.46 at location [752.1, 415.1, 883.3, 465.9]
# plot/f1/2023-04-17-15h-00m-15s.jpg
# Detected 1 with confidence 0.57 at location [581.5, 392.7, 703.1, 441.0]
# plot/f1/2023-04-17-15h-09m-16s.jpg
# Detected 1 with confidence 0.39 at location [560.4, 303.2, 646.7, 347.0]
# plot/f1/2023-04-17-15h-43m-50s.jpg
# Detected 1 with confidence 0.46 at location [754.7, 353.1, 843.0, 419.0]
# plot/f1/2023-04-17-16h-09m-29s.jpg
# Detected 1 with confidence 0.38 at location [931.7, 506.0, 971.1, 594.9]
# plot/f1/2023-04-18-11h-31m-32s.jpg
# Detected 1 with confidence 0.47 at location [679.1, 332.6, 709.5, 389.7]
# plot/f1/2023-04-19-13h-43m-18s.jpg
# plot/f1/2023-04-19-14h-23m-59s.jpg
# Detected 1 with confidence 0.48 at location [799.4, 352.1, 854.2, 434.3]
# plot/f1/2023-04-19-14h-41m-13s.jpg
# Detected 1 with confidence 0.36 at location [560.8, 486.7, 668.6, 608.5]
# plot/f1/2023-04-19-17h-15m-05s.jpg
# Detected 1 with confidence 0.41 at location [681.3, 474.5, 746.3, 496.8]
# plot/f1/2023-04-19-17h-53m-26s.jpg
# Detected 1 with confidence 0.51 at location [779.2, 448.6, 898.4, 521.4]
# plot/f1/2023-04-20-13h-00m-56s.jpg
# Detected 1 with confidence 0.52 at location [633.7, 516.1, 737.4, 545.4]
# plot/f1/2023-04-20-13h-13m-17s.jpg
# Detected 1 with confidence 0.46 at location [763.1, 496.6, 863.1, 535.2]
# plot/f1/2023-04-20-13h-58m-36s.jpg
# Detected 1 with confidence 0.42 at location [734.7, 460.9, 787.8, 495.9]
# plot/f1/2023-04-20-14h-25m-04s.jpg
# Detected 1 with confidence 0.46 at location [595.1, 504.5, 683.0, 530.2]
# plot/f1/2023-04-20-14h-36m-31s.jpg
# Detected 1 with confidence 0.45 at location [745.9, 487.6, 836.0, 509.8]
# plot/f1/2023-04-20-14h-49m-07s.jpg
# Detected 1 with confidence 0.41 at location [733.4, 457.2, 807.4, 476.5]
# plot/f1/2023-04-20-14h-57m-42s.jpg
# Detected 1 with confidence 0.42 at location [824.2, 482.4, 888.0, 501.2]
# plot/f1/2023-04-20-23h-24m-41s.jpg
# Detected 1 with confidence 0.57 at location [620.5, 317.0, 709.6, 377.6]
# plot/f1/2023-04-21-00h-34m-24s.jpg
# plot/f1/2023-04-21-21h-02m-57s.jpg
# plot/f1/2023-04-21-21h-42m-05s.jpg
# Detected 1 with confidence 0.35 at location [715.7, 371.0, 810.4, 413.2]
# plot/f1/2023-04-24-16h-33m-21s.jpg
# plot/f1/2023-04-24-16h-55m-53s.jpg
# Detected 1 with confidence 0.39 at location [644.1, 421.5, 760.6, 465.5]
# plot/f1/2023-04-26-09h-32m-54s.jpg
# Detected 1 with confidence 0.56 at location [712.8, 482.6, 817.4, 526.4]
# plot/f1/2023-04-26-10h-21m-05s.jpg
# Detected 1 with confidence 0.42 at location [421.1, 267.4, 524.9, 300.1]
# plot/f1/2023-04-27-15h-15m-24s.jpg
# Detected 1 with confidence 0.67 at location [836.1, 383.6, 946.1, 472.9]
# plot/f1/2023-04-29-19h-26m-53s.jpg
# Detected 1 with confidence 0.52 at location [126.3, 545.8, 306.0, 714.7]
# plot/f1/2023-04-30-12h-48m-09s.jpg
# Detected 1 with confidence 0.55 at location [728.3, 520.6, 803.3, 562.5]
# plot/f1/2023-04-30-12h-59m-43s.jpg
# Detected 1 with confidence 0.55 at location [667.6, 481.7, 746.9, 519.5]
# plot/f1/2023-04-30-13h-14m-39s.jpg
# Detected 1 with confidence 0.5 at location [734.5, 478.6, 776.7, 520.0]
# plot/f1/2023-04-30-13h-22m-37s.jpg
# Detected 1 with confidence 0.48 at location [649.2, 563.8, 748.1, 597.5]
# plot/f1/2023-04-30-19h-42m-21s.jpg
# Detected 1 with confidence 0.35 at location [320.1, 525.7, 525.7, 601.8]
# Detected 1 with confidence 0.38 at location [344.5, 546.1, 476.7, 590.5]
# plot/f1/2023-05-03-09h-21m-34s.jpg
# Detected 1 with confidence 0.36 at location [644.3, 386.5, 706.5, 449.6]
# plot/f1/2023-05-03-10h-02m-52s.jpg
# Detected 1 with confidence 0.5 at location [714.9, 542.4, 810.0, 600.8]
# plot/f1/2023-05-05-10h-38m-25s.jpg
# Detected 1 with confidence 0.36 at location [474.4, 278.7, 555.8, 302.4]
# plot/f1/2023-05-05-11h-07m-46s.jpg
# Detected 1 with confidence 0.39 at location [390.8, 399.4, 507.4, 431.0]
# plot/f1/2023-05-05-11h-24m-07s.jpg
# Detected 1 with confidence 0.42 at location [401.8, 263.3, 471.4, 326.8]
# plot/f1/2023-05-05-11h-48m-42s.jpg
# Detected 1 with confidence 0.53 at location [468.5, 433.4, 568.6, 502.1]
# plot/f1/2023-05-07-16h-21m-25s.jpg
# Detected 1 with confidence 0.45 at location [716.5, 396.3, 753.4, 465.2]
# plot/f1/2023-05-08-15h-21m-01s.jpg
# plot/f1/2023-05-08-16h-04m-41s.jpg
# plot/f1/2023-05-11-14h-10m-46s.jpg
# Detected 1 with confidence 0.39 at location [526.3, 367.7, 607.1, 401.8]
# plot/f1/2023-05-11-14h-58m-27s.jpg
# Detected 1 with confidence 0.59 at location [694.4, 410.5, 749.2, 507.3]
# plot/f1/2023-05-11-15h-40m-44s.jpg
# Detected 1 with confidence 0.41 at location [563.3, 248.8, 613.9, 296.1]
# plot/f1/2023-05-12-11h-12m-58s.jpg
# Detected 1 with confidence 0.38 at location [649.6, 359.0, 756.5, 385.3]
# plot/f1/2023-05-15-22h-56m-32s.jpg
# Detected 1 with confidence 0.74 at location [741.5, 362.3, 847.0, 449.8]
# plot/f1/2023-05-15-23h-27m-29s.jpg
# Detected 1 with confidence 0.76 at location [887.9, 375.3, 1016.6, 446.5]
# plot/f1/2023-05-16-14h-06m-19s.jpg
# Detected 1 with confidence 0.65 at location [1084.1, 380.3, 1278.2, 421.9]
# plot/f1/2023-05-16-14h-49m-49s.jpg
# Detected 1 with confidence 0.75 at location [1120.7, 409.4, 1278.0, 511.0]
# plot/f1/2023-05-16-15h-45m-28s.jpg
# Detected 1 with confidence 0.72 at location [960.6, 306.0, 1158.0, 351.0]
# plot/f1/2023-05-16-19h-17m-20s.jpg
# Detected 1 with confidence 0.73 at location [842.9, 322.7, 910.9, 417.9]
# plot/f1/2023-05-16-19h-52m-35s.jpg
# Detected 1 with confidence 0.69 at location [783.9, 348.4, 911.6, 402.7]
# plot/f1/2023-05-16-22h-10m-49s.jpg
# Detected 1 with confidence 0.68 at location [962.3, 346.6, 1093.9, 426.7]
# plot/f1/2023-05-17-18h-15m-55s.jpg
# Detected 1 with confidence 0.48 at location [837.1, 233.4, 909.2, 287.8]
# plot/f1/2023-05-17-19h-17m-25s.jpg
# Detected 1 with confidence 0.69 at location [694.7, 390.1, 782.3, 455.3]
# plot/f1/2023-05-17-22h-14m-00s.jpg
# Detected 1 with confidence 0.52 at location [596.7, 282.7, 650.3, 345.7]
# plot/f1/2023-05-18-17h-58m-55s.jpg
# Detected 1 with confidence 0.63 at location [498.0, 337.4, 561.8, 396.7]
# plot/f1/2023-05-18-19h-19m-12s.jpg
# Detected 1 with confidence 0.8 at location [655.2, 395.1, 792.3, 452.3]
# plot/f1/2023-05-18-20h-44m-38s.jpg
# Detected 1 with confidence 0.75 at location [529.5, 441.5, 673.2, 524.8]
# plot/f1/2023-05-18-20h-59m-54s.jpg
# Detected 1 with confidence 0.59 at location [740.2, 312.6, 851.2, 349.5]
# plot/f1/2023-05-20-15h-28m-22s.jpg
# Detected 1 with confidence 0.39 at location [147.4, 513.6, 374.7, 594.9]
# plot/f1/2023-05-20-17h-02m-18s.jpg
# plot/f1/2023-05-22-11h-54m-19s.jpg
# Detected 1 with confidence 0.66 at location [859.3, 248.0, 984.6, 308.4]
# plot/f1/2023-05-28-17h-25m-08s.jpg
# Detected 1 with confidence 0.47 at location [485.5, 533.2, 608.0, 687.6]
# plot/f1/2023-06-02-11h-01m-46s.jpg
# Detected 1 with confidence 0.4 at location [605.5, 454.2, 638.5, 498.7]
# plot/f1/2023-06-20-03h-13m-03s.jpg
# Detected 1 with confidence 0.39 at location [755.7, 634.3, 865.5, 660.2]
# plot/f1/2023-06-25-17h-20m-27s.jpg
# Detected 1 with confidence 0.51 at location [784.9, 426.9, 840.5, 478.2]
# plot/f1/2023-07-19-19h-34m-28s.jpg
# Detected 1 with confidence 0.41 at location [609.4, 158.4, 643.9, 239.4]
# plot/f1/2023-08-12-18h-57m-44s.jpg
# plot/f1/2023-08-23-20h-53m-08s.jpg
# Detected 1 with confidence 0.42 at location [646.1, 605.4, 715.7, 705.6]
# plot/f1/2023-09-21-09h-37m-41s.jpg
# Detected 1 with confidence 0.48 at location [684.8, 590.3, 725.4, 653.9]
# plot/f1/2023-09-21-11h-32m-13s.jpg
# plot/f1/2023-09-21-15h-13m-19s.jpg
# Detected 1 with confidence 0.35 at location [527.2, 356.8, 558.8, 382.7]
# plot/f1/2023-09-21-16h-54m-25s.jpg
# Detected 1 with confidence 0.51 at location [827.5, 448.5, 922.9, 519.9]
# plot/f1/2023-11-28-08h-58m-15s.jpg
# Detected 1 with confidence 0.5 at location [381.0, 635.4, 497.8, 716.1]

# %%
box_list
# Out:
# [('2023-03-02-15h-03m-35s', []),
#  ('2023-03-02-16h-51m-12s', [([637.4, 431.0, 708.3, 452.1], 0.42)]),
#  ('2023-03-02-18h-13m-38s', [([565.0, 562.0, 673.2, 601.1], 0.53)]),
#  ('2023-03-03-15h-30m-17s', [([538.0, 359.1, 682.0, 407.5], 0.42)]),
#  ('2023-03-06-16h-02m-37s', [([740.7, 427.2, 886.6, 489.2], 0.49)]),
#  ('2023-03-06-17h-06m-52s', [([651.6, 379.2, 696.3, 446.9], 0.43)]),
#  ('2023-03-07-15h-36m-10s', [([676.0, 351.4, 741.2, 382.8], 0.43)]),
#  ('2023-03-07-16h-20m-41s', []),
#  ('2023-03-07-17h-59m-19s', []),
#  ('2023-03-08-13h-29m-47s', []),
#  ('2023-03-08-14h-45m-19s', [([780.7, 403.2, 858.7, 451.7], 0.49)]),
#  ('2023-03-08-16h-45m-10s', [([816.3, 435.1, 900.4, 498.0], 0.55)]),
#  ('2023-03-08-19h-32m-03s', [([578.2, 562.9, 611.4, 631.6], 0.55)]),
#  ('2023-03-08-19h-51m-18s', [([550.4, 457.0, 599.1, 496.6], 0.4)]),
#  ('2023-03-09-18h-14m-34s', [([722.0, 452.9, 740.3, 498.6], 0.41)]),
#  ('2023-03-09-18h-47m-35s', [([594.0, 377.2, 664.2, 405.3], 0.38)]),
#  ('2023-03-09-19h-48m-15s', [([703.0, 327.4, 788.0, 353.1], 0.39)]),
#  ('2023-04-07-13h-32m-40s', [([872.6, 359.8, 897.8, 413.3], 0.42)]),
#  ('2023-04-12-14h-13m-32s', [([539.5, 303.5, 614.6, 356.8], 0.49)]),
#  ('2023-04-12-15h-09m-51s', []),
#  ('2023-04-12-15h-34m-49s', []),
#  ('2023-04-12-15h-59m-04s', [([737.9, 367.0, 860.4, 406.5], 0.45)]),
#  ('2023-04-12-16h-45m-27s', [([690.9, 430.0, 827.3, 465.9], 0.43)]),
#  ('2023-04-13-15h-21m-15s', [([341.0, 629.3, 399.3, 708.2], 0.46)]),
#  ('2023-04-17-14h-47m-13s', [([752.1, 415.1, 883.3, 465.9], 0.46)]),
#  ('2023-04-17-15h-00m-15s', [([581.5, 392.7, 703.1, 441.0], 0.57)]),
#  ('2023-04-17-15h-09m-16s', [([560.4, 303.2, 646.7, 347.0], 0.39)]),
#  ('2023-04-17-15h-43m-50s', [([754.7, 353.1, 843.0, 419.0], 0.46)]),
#  ('2023-04-17-16h-09m-29s', [([931.7, 506.0, 971.1, 594.9], 0.38)]),
#  ('2023-04-18-11h-31m-32s', [([679.1, 332.6, 709.5, 389.7], 0.47)]),
#  ('2023-04-19-13h-43m-18s', []),
#  ('2023-04-19-14h-23m-59s', [([799.4, 352.1, 854.2, 434.3], 0.48)]),
#  ('2023-04-19-14h-41m-13s', [([560.8, 486.7, 668.6, 608.5], 0.36)]),
#  ('2023-04-19-17h-15m-05s', [([681.3, 474.5, 746.3, 496.8], 0.41)]),
#  ('2023-04-19-17h-53m-26s', [([779.2, 448.6, 898.4, 521.4], 0.51)]),
#  ('2023-04-20-13h-00m-56s', [([633.7, 516.1, 737.4, 545.4], 0.52)]),
#  ('2023-04-20-13h-13m-17s', [([763.1, 496.6, 863.1, 535.2], 0.46)]),
#  ('2023-04-20-13h-58m-36s', [([734.7, 460.9, 787.8, 495.9], 0.42)]),
#  ('2023-04-20-14h-25m-04s', [([595.1, 504.5, 683.0, 530.2], 0.46)]),
#  ('2023-04-20-14h-36m-31s', [([745.9, 487.6, 836.0, 509.8], 0.45)]),
#  ('2023-04-20-14h-49m-07s', [([733.4, 457.2, 807.4, 476.5], 0.41)]),
#  ('2023-04-20-14h-57m-42s', [([824.2, 482.4, 888.0, 501.2], 0.42)]),
#  ('2023-04-20-23h-24m-41s', [([620.5, 317.0, 709.6, 377.6], 0.57)]),
#  ('2023-04-21-00h-34m-24s', []),
#  ('2023-04-21-21h-02m-57s', []),
#  ('2023-04-21-21h-42m-05s', [([715.7, 371.0, 810.4, 413.2], 0.35)]),
#  ('2023-04-24-16h-33m-21s', []),
#  ('2023-04-24-16h-55m-53s', [([644.1, 421.5, 760.6, 465.5], 0.39)]),
#  ('2023-04-26-09h-32m-54s', [([712.8, 482.6, 817.4, 526.4], 0.56)]),
#  ('2023-04-26-10h-21m-05s', [([421.1, 267.4, 524.9, 300.1], 0.42)]),
#  ('2023-04-27-15h-15m-24s', [([836.1, 383.6, 946.1, 472.9], 0.67)]),
#  ('2023-04-29-19h-26m-53s', [([126.3, 545.8, 306.0, 714.7], 0.52)]),
#  ('2023-04-30-12h-48m-09s', [([728.3, 520.6, 803.3, 562.5], 0.55)]),
#  ('2023-04-30-12h-59m-43s', [([667.6, 481.7, 746.9, 519.5], 0.55)]),
#  ('2023-04-30-13h-14m-39s', [([734.5, 478.6, 776.7, 520.0], 0.5)]),
#  ('2023-04-30-13h-22m-37s', [([649.2, 563.8, 748.1, 597.5], 0.48)]),
#  ('2023-04-30-19h-42m-21s',
#   [([320.1, 525.7, 525.7, 601.8], 0.35),
#    ([344.5, 546.1, 476.7, 590.5], 0.38)]),
#  ('2023-05-03-09h-21m-34s', [([644.3, 386.5, 706.5, 449.6], 0.36)]),
#  ('2023-05-03-10h-02m-52s', [([714.9, 542.4, 810.0, 600.8], 0.5)]),
#  ('2023-05-05-10h-38m-25s', [([474.4, 278.7, 555.8, 302.4], 0.36)]),
#  ('2023-05-05-11h-07m-46s', [([390.8, 399.4, 507.4, 431.0], 0.39)]),
#  ('2023-05-05-11h-24m-07s', [([401.8, 263.3, 471.4, 326.8], 0.42)]),
#  ('2023-05-05-11h-48m-42s', [([468.5, 433.4, 568.6, 502.1], 0.53)]),
#  ('2023-05-07-16h-21m-25s', [([716.5, 396.3, 753.4, 465.2], 0.45)]),
#  ('2023-05-08-15h-21m-01s', []),
#  ('2023-05-08-16h-04m-41s', []),
#  ('2023-05-11-14h-10m-46s', [([526.3, 367.7, 607.1, 401.8], 0.39)]),
#  ('2023-05-11-14h-58m-27s', [([694.4, 410.5, 749.2, 507.3], 0.59)]),
#  ('2023-05-11-15h-40m-44s', [([563.3, 248.8, 613.9, 296.1], 0.41)]),
#  ('2023-05-12-11h-12m-58s', [([649.6, 359.0, 756.5, 385.3], 0.38)]),
#  ('2023-05-15-22h-56m-32s', [([741.5, 362.3, 847.0, 449.8], 0.74)]),
#  ('2023-05-15-23h-27m-29s', [([887.9, 375.3, 1016.6, 446.5], 0.76)]),
#  ('2023-05-16-14h-06m-19s', [([1084.1, 380.3, 1278.2, 421.9], 0.65)]),
#  ('2023-05-16-14h-49m-49s', [([1120.7, 409.4, 1278.0, 511.0], 0.75)]),
#  ('2023-05-16-15h-45m-28s', [([960.6, 306.0, 1158.0, 351.0], 0.72)]),
#  ('2023-05-16-19h-17m-20s', [([842.9, 322.7, 910.9, 417.9], 0.73)]),
#  ('2023-05-16-19h-52m-35s', [([783.9, 348.4, 911.6, 402.7], 0.69)]),
#  ('2023-05-16-22h-10m-49s', [([962.3, 346.6, 1093.9, 426.7], 0.68)]),
#  ('2023-05-17-18h-15m-55s', [([837.1, 233.4, 909.2, 287.8], 0.48)]),
#  ('2023-05-17-19h-17m-25s', [([694.7, 390.1, 782.3, 455.3], 0.69)]),
#  ('2023-05-17-22h-14m-00s', [([596.7, 282.7, 650.3, 345.7], 0.52)]),
#  ('2023-05-18-17h-58m-55s', [([498.0, 337.4, 561.8, 396.7], 0.63)]),
#  ('2023-05-18-19h-19m-12s', [([655.2, 395.1, 792.3, 452.3], 0.8)]),
#  ('2023-05-18-20h-44m-38s', [([529.5, 441.5, 673.2, 524.8], 0.75)]),
#  ('2023-05-18-20h-59m-54s', [([740.2, 312.6, 851.2, 349.5], 0.59)]),
#  ('2023-05-20-15h-28m-22s', [([147.4, 513.6, 374.7, 594.9], 0.39)]),
#  ('2023-05-20-17h-02m-18s', []),
#  ('2023-05-22-11h-54m-19s', [([859.3, 248.0, 984.6, 308.4], 0.66)]),
#  ('2023-05-28-17h-25m-08s', [([485.5, 533.2, 608.0, 687.6], 0.47)]),
#  ('2023-06-02-11h-01m-46s', [([605.5, 454.2, 638.5, 498.7], 0.4)]),
#  ('2023-06-20-03h-13m-03s', [([755.7, 634.3, 865.5, 660.2], 0.39)]),
#  ('2023-06-25-17h-20m-27s', [([784.9, 426.9, 840.5, 478.2], 0.51)]),
#  ('2023-07-19-19h-34m-28s', [([609.4, 158.4, 643.9, 239.4], 0.41)]),
#  ('2023-08-12-18h-57m-44s', []),
#  ('2023-08-23-20h-53m-08s', [([646.1, 605.4, 715.7, 705.6], 0.42)]),
#  ('2023-09-21-09h-37m-41s', [([684.8, 590.3, 725.4, 653.9], 0.48)]),
#  ('2023-09-21-11h-32m-13s', []),
#  ('2023-09-21-15h-13m-19s', [([527.2, 356.8, 558.8, 382.7], 0.35)]),
#  ('2023-09-21-16h-54m-25s', [([827.5, 448.5, 922.9, 519.9], 0.51)]),
#  ('2023-11-28-08h-58m-15s', [([381.0, 635.4, 497.8, 716.1], 0.5)])]
