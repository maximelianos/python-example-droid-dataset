# %%
import requests

import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForZeroShotObjectDetection

model_id = "IDEA-Research/grounding-dino-base"

processor = AutoProcessor.from_pretrained(model_id)
device = "cuda"
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)
# Out:
# 2024-07-23 14:11:42.273831: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-23 14:11:42.289388: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-23 14:11:42.289412: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-23 14:11:42.299251: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-23 14:11:43.008708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from pathlib import Path

def run_sam(image, text):
    inputs = processor(images=image, text=text, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = model(**inputs)
    
    # convert outputs (bounding boxes and class logits) to COCO API
    
    target_sizes = torch.tensor([image.size[::-1]])
    
    results = processor.image_processor.post_process_object_detection(
    
        outputs, threshold=0.35, target_sizes=target_sizes
    
    )[0]

    box_list = []
    for score, label, box in zip(results["scores"], results["labels"], results["boxes"]):
    
        box = [round(i, 1) for i in box.tolist()]
        conf = round(score.item(), 2)
        box_list.append((box, conf))
    
        print(f"Detected {label.item()} with confidence " f"{round(score.item(), 2)} at location {box}")
    return box_list

# %%
import ultralytics
from ultralytics.utils.plotting import Annotator
import cv2

file_list = sorted(Path("plot/f1").glob("*jpg"))
print("episodes:", len(file_list))
# file_list = file_list[:10]

for file in file_list:
    print(file)
    image = Image.open(file)
    # Check for cats and remote controls
    text = "a pen."

    boxes = run_sam(image, text)

    plot_path = Path("plot/detect") / (file.name)
    plot_path.parent.mkdir(parents=True, exist_ok=True)

    annotator = Annotator(image)
    for box, conf in boxes:
        annotator.box_label(box, label=str(conf), color=(0, 204, 0)) # The bounding box coordinates (x1, y1, x2, y2)
    
    result = annotator.result()
    cv2.imwrite(plot_path, cv2.cvtColor(result, cv2.COLOR_RGB2BGR), [cv2.IMWRITE_JPEG_QUALITY, 100])
# Out:
# episodes: 52
# plot/f1/2023-03-02-14h-58m-51s.jpg
# Detected 1 with confidence 0.36 at location [775.5, 341.5, 819.2, 383.7]
# plot/f1/2023-03-02-16h-53m-07s.jpg
# Detected 1 with confidence 0.38 at location [732.3, 381.9, 750.8, 417.4]
# plot/f1/2023-03-03-15h-54m-59s.jpg
# plot/f1/2023-03-06-16h-13m-25s.jpg
# Detected 1 with confidence 0.62 at location [754.4, 468.8, 922.7, 553.5]
# plot/f1/2023-03-06-17h-24m-17s.jpg
# Detected 1 with confidence 0.42 at location [719.4, 363.4, 807.1, 424.8]
# plot/f1/2023-03-07-16h-16m-38s.jpg
# Detected 1 with confidence 0.41 at location [650.6, 292.7, 715.4, 342.0]
# plot/f1/2023-03-07-17h-57m-28s.jpg
# Detected 1 with confidence 0.43 at location [710.5, 494.8, 780.7, 555.4]
# plot/f1/2023-03-08-13h-31m-50s.jpg
# plot/f1/2023-03-08-14h-52m-01s.jpg
# Detected 1 with confidence 0.41 at location [730.6, 279.5, 755.4, 335.2]
# plot/f1/2023-03-08-19h-36m-27s.jpg
# Detected 1 with confidence 0.35 at location [684.3, 543.6, 752.6, 607.7]
# plot/f1/2023-03-08-19h-55m-12s.jpg
# Detected 1 with confidence 0.43 at location [586.5, 491.4, 624.0, 543.5]
# plot/f1/2023-03-09-18h-33m-11s.jpg
# Detected 1 with confidence 0.4 at location [518.5, 438.6, 624.2, 463.5]
# Detected 2 with confidence 0.35 at location [448.0, 311.1, 1030.6, 707.6]
# plot/f1/2023-04-07-13h-23m-33s.jpg
# plot/f1/2023-04-07-13h-52m-47s.jpg
# plot/f1/2023-04-12-14h-03m-39s.jpg
# Detected 1 with confidence 0.51 at location [686.3, 310.7, 769.7, 361.9]
# plot/f1/2023-04-12-14h-13m-32s.jpg
# Detected 1 with confidence 0.49 at location [539.5, 303.5, 614.6, 356.8]
# plot/f1/2023-04-12-15h-44m-53s.jpg
# Detected 1 with confidence 0.47 at location [760.6, 377.2, 881.1, 418.5]
# plot/f1/2023-04-12-16h-23m-05s.jpg
# Detected 1 with confidence 0.44 at location [560.8, 492.1, 671.7, 611.9]
# plot/f1/2023-04-12-16h-42m-15s.jpg
# Detected 1 with confidence 0.45 at location [712.3, 441.5, 852.9, 473.5]
# plot/f1/2023-04-17-15h-05m-20s.jpg
# Detected 1 with confidence 0.37 at location [561.2, 308.4, 624.9, 367.9]
# plot/f1/2023-04-17-15h-44m-47s.jpg
# Detected 1 with confidence 0.43 at location [864.3, 448.1, 968.9, 495.1]
# plot/f1/2023-04-19-13h-45m-01s.jpg
# plot/f1/2023-04-19-14h-35m-48s.jpg
# Detected 1 with confidence 0.55 at location [728.9, 366.3, 832.7, 429.5]
# plot/f1/2023-04-20-13h-08m-08s.jpg
# Detected 1 with confidence 0.42 at location [686.9, 500.3, 776.5, 540.1]
# plot/f1/2023-04-20-13h-18m-51s.jpg
# plot/f1/2023-04-20-14h-28m-23s.jpg
# Detected 1 with confidence 0.38 at location [760.5, 474.8, 827.3, 494.6]
# plot/f1/2023-04-20-14h-55m-05s.jpg
# Detected 1 with confidence 0.46 at location [630.6, 485.1, 719.3, 507.7]
# plot/f1/2023-04-20-23h-28m-09s.jpg
# plot/f1/2023-04-27-15h-36m-34s.jpg
# Detected 1 with confidence 0.44 at location [720.4, 451.1, 804.2, 512.0]
# plot/f1/2023-04-30-12h-58m-37s.jpg
# Detected 1 with confidence 0.51 at location [674.0, 501.7, 765.5, 533.1]
# plot/f1/2023-04-30-13h-00m-23s.jpg
# Detected 1 with confidence 0.57 at location [665.7, 512.7, 764.8, 547.1]
# plot/f1/2023-04-30-13h-03m-40s.jpg
# Detected 1 with confidence 0.63 at location [689.7, 509.1, 781.5, 555.0]
# plot/f1/2023-04-30-19h-25m-57s.jpg
# Detected 1 with confidence 0.55 at location [351.8, 536.3, 503.6, 564.2]
# plot/f1/2023-04-30-19h-43m-58s.jpg
# Detected 1 with confidence 0.38 at location [313.7, 527.1, 525.4, 617.4]
# Detected 1 with confidence 0.35 at location [319.6, 528.1, 487.8, 582.4]
# plot/f1/2023-05-05-11h-15m-43s.jpg
# Detected 1 with confidence 0.45 at location [460.6, 363.5, 559.2, 395.8]
# plot/f1/2023-05-08-14h-54m-31s.jpg
# Detected 1 with confidence 0.41 at location [577.6, 265.5, 678.7, 310.6]
# plot/f1/2023-05-11-14h-50m-08s.jpg
# Detected 1 with confidence 0.39 at location [572.7, 323.2, 640.7, 386.3]
# plot/f1/2023-05-11-15h-49m-17s.jpg
# Detected 1 with confidence 0.39 at location [630.0, 230.1, 733.1, 254.9]
# plot/f1/2023-05-15-22h-53m-34s.jpg
# Detected 1 with confidence 0.63 at location [637.9, 351.2, 748.2, 384.7]
# plot/f1/2023-05-16-14h-25m-33s.jpg
# Detected 1 with confidence 0.79 at location [929.3, 578.1, 1063.6, 716.1]
# plot/f1/2023-05-16-19h-16m-13s.jpg
# Detected 1 with confidence 0.81 at location [769.4, 317.9, 879.5, 398.3]
# plot/f1/2023-05-16-19h-35m-32s.jpg
# Detected 1 with confidence 0.5 at location [836.9, 348.3, 896.8, 393.6]
# plot/f1/2023-05-16-21h-55m-39s.jpg
# Detected 1 with confidence 0.82 at location [576.9, 506.1, 702.3, 645.6]
# plot/f1/2023-05-16-21h-58m-01s.jpg
# Detected 1 with confidence 0.44 at location [750.1, 321.8, 829.4, 371.9]
# plot/f1/2023-05-17-19h-08m-06s.jpg
# Detected 1 with confidence 0.64 at location [667.2, 388.4, 719.3, 470.1]
# plot/f1/2023-05-17-19h-21m-00s.jpg
# Detected 1 with confidence 0.59 at location [653.2, 407.6, 729.5, 461.0]
# plot/f1/2023-05-17-21h-37m-15s.jpg
# Detected 1 with confidence 0.58 at location [757.9, 334.9, 805.1, 405.2]
# plot/f1/2023-05-18-18h-09m-06s.jpg
# Detected 1 with confidence 0.46 at location [567.0, 423.8, 678.1, 461.2]
# plot/f1/2023-05-18-20h-39m-10s.jpg
# plot/f1/2023-05-20-15h-25m-58s.jpg
# Detected 1 with confidence 0.48 at location [945.0, 313.6, 1011.7, 344.4]
# plot/f1/2023-05-22-12h-22m-59s.jpg
# Detected 1 with confidence 0.67 at location [911.7, 249.3, 1035.3, 327.1]
# plot/f1/2023-10-26-10h-42m-01s.jpg
# Detected 1 with confidence 0.48 at location [652.8, 430.1, 721.4, 460.2]

# %%
# Out:
# True
